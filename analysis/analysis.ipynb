# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## Estratificação

# %%
df = pd.read_csv('../data/sp_sao_paulo.csv', low_memory=False)
df = df[['DATA_DO_PEDIDO','RAZAO_SOCIAL','DESCRICAO_DO_PRODUTO','SUB_BU','PRECO','QUANTIDADE_FATURADA']]
df['DATA_DO_PEDIDO'] = pd.to_datetime(df['DATA_DO_PEDIDO'], dayfirst=True).dt.strftime('%Y-%m')
df = df.query('PRECO > 0.0')
df.dropna()
df.head()
# Out:
#   DATA_DO_PEDIDO         RAZAO_SOCIAL  \
# 0        2020-11  DROGAMELLO DROGARIA
# 1        2020-11  NOVA MELLO DROGARIA
# 2        2020-11  NOVA MELLO DROGARIA
# 3        2020-11  NOVA MELLO DROGARIA
# 4        2020-11  NOVA MELLO DROGARIA
#
#                       DESCRICAO_DO_PRODUTO     SUB_BU  PRECO  \
# 0  CENTROTABS CABELOS E UNHAS CT FR 60 CAP      SMART   8.49
# 1    NEOLEFRIN XPE FR VD AMB 60ML+COPO MED      SMART   5.13
# 2     COLIRIO NEO BRASIL SOL OFT FR C/20ML      SMART   4.58
# 3       CIPROFIBRATO 100MG CT BL 2X15 COMP  GENÉRICOS  10.48
# 4                  TORSILAX CT BL 2X6 COMP      SMART   2.43
#
#    QUANTIDADE_FATURADA
# 0                   60
# 1                   12
# 2                   12
# 3                   12
# 4                  140

# %%
#{ 'PRECO':['mean'] , 'QUANTIDADE_FATURADA':['sum']}
df_g = df.groupby(['DATA_DO_PEDIDO','RAZAO_SOCIAL','DESCRICAO_DO_PRODUTO','SUB_BU'],as_index=False).agg(PRECO_MEDIO=('PRECO','mean'),QUANTIDADE_TOTAL = ('QUANTIDADE_FATURADA','sum'))
df_g
# Out:
#       DATA_DO_PEDIDO                              RAZAO_SOCIAL  \
# 0            2020-11             A.R. NETO DROGARIAS LTDA - ME
# 1            2020-11             A.R. NETO DROGARIAS LTDA - ME
# 2            2020-11             A.R. NETO DROGARIAS LTDA - ME
# 3            2020-11             A.R. NETO DROGARIAS LTDA - ME
# 4            2020-11             A.R. NETO DROGARIAS LTDA - ME
# ...              ...                                       ...
# 46666        2021-12  ZLZ DROG COM VAREJISTA DE PROD FARMACS E
# 46667        2021-12  ZLZ DROG COM VAREJISTA DE PROD FARMACS E
# 46668        2021-12  ZLZ DROG COM VAREJISTA DE PROD FARMACS E
# 46669        2021-12  ZLZ DROG COM VAREJISTA DE PROD FARMACS E
# 46670        2021-12  ZLZ DROG COM VAREJISTA DE PROD FARMACS E
#
#                           DESCRICAO_DO_PRODUTO     SUB_BU  PRECO_MEDIO  \
# 0           CIPROFIBRATO 100MG CT BL 2X15 COMP  GENÉRICOS        10.48
# 1      DIPIRONA 500MG CAFEINA 65MG CT 2X8 COMP  GENÉRICOS         8.02
# 2        DRAMAVIT B6 SOL OR CT FR PET 20 ML LP      SMART         4.16
# 3             EQUILIBRISSE CT BL AL 420MG X 10      SMART         6.20
# 4              GLIBENCLAMIDA 5MG CT BL 30 COMP  GENÉRICOS         1.05
# ...                                        ...        ...          ...
# 46666           HISTAMIN CREME 10MG/G BG C/30G      SMART         5.94
# 46667                  NEOLEFRIN CT BL 20 COMP      SMART         2.76
# 46668              NEOLEFRIN DIA CT BL 20 COMP      SMART         2.30
# 46669    NEOLEFRIN XPE FR VD AMB 60ML+COPO MED      SMART         4.80
# 46670     PROP DE CLOBETASOL 0,5MG/G CR BG 30G  GENÉRICOS        11.47
#
#        QUANTIDADE_TOTAL
# 0                    10
# 1                     6
# 2                     3
# 3                     6
# 4                     5
# ...                 ...
# 46666                 3
# 46667                 8
# 46668                 4
# 46669                 2
# 46670                10
#
# [46671 rows x 6 columns]

# %% [markdown]
# ## Modelagem

# %%
# split data into train-test set
train = df_g[df_g['DATA_DO_PEDIDO'] < '2021-08']
test =  df_g[df_g['DATA_DO_PEDIDO'] >= '2021-08']

# %%
# import the regression module
from pycaret.regression import *
# initialize setup
s = setup(data=train,
          preprocess=True,
          test_data=test,
          target='QUANTIDADE_TOTAL',
          fold_strategy='timeseries',
          fold=3, 
          transform_target=True,
          remove_outliers = True,
          pca=False,
          pca_method ="kernel",
          session_id=123)
# Out:
# <style type="text/css">
# #T_65ffb_row38_col1, #T_65ffb_row42_col1, #T_65ffb_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_65ffb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65ffb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_65ffb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65ffb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65ffb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_65ffb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_65ffb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_65ffb_row1_col1" class="data row1 col1" >QUANTIDADE_TOTAL</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_65ffb_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_65ffb_row2_col1" class="data row2 col1" >(30528, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_65ffb_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_65ffb_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_65ffb_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_65ffb_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_65ffb_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_65ffb_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_65ffb_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_65ffb_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_65ffb_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_65ffb_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_65ffb_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_65ffb_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_65ffb_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_65ffb_row9_col1" class="data row9 col1" >(29001, 449)</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_65ffb_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_65ffb_row10_col1" class="data row10 col1" >(16143, 449)</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_65ffb_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_65ffb_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_65ffb_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_65ffb_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_65ffb_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_65ffb_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_65ffb_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_65ffb_row14_col1" class="data row14 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_65ffb_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_65ffb_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_65ffb_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_65ffb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_65ffb_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_65ffb_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_65ffb_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_65ffb_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_65ffb_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_65ffb_row19_col1" class="data row19 col1" >e900</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_65ffb_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_65ffb_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_65ffb_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_65ffb_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_65ffb_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_65ffb_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_65ffb_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_65ffb_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_65ffb_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_65ffb_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_65ffb_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_65ffb_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_65ffb_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_65ffb_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_65ffb_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_65ffb_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_65ffb_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_65ffb_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_65ffb_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_65ffb_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_65ffb_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_65ffb_row30_col0" class="data row30 col0" >Tra

# %%
best = compare_models(sort = 'RMSE')
# Out:
# <style type="text/css">
# #T_3e2e9 th {
#   text-align: left;
# }
# #T_3e2e9_row0_col0, #T_3e2e9_row0_col5, #T_3e2e9_row0_col6, #T_3e2e9_row1_col0, #T_3e2e9_row1_col1, #T_3e2e9_row1_col2, #T_3e2e9_row1_col3, #T_3e2e9_row1_col4, #T_3e2e9_row1_col5, #T_3e2e9_row1_col6, #T_3e2e9_row2_col0, #T_3e2e9_row2_col1, #T_3e2e9_row2_col2, #T_3e2e9_row2_col3, #T_3e2e9_row2_col4, #T_3e2e9_row2_col5, #T_3e2e9_row2_col6, #T_3e2e9_row3_col0, #T_3e2e9_row3_col1, #T_3e2e9_row3_col2, #T_3e2e9_row3_col3, #T_3e2e9_row3_col4, #T_3e2e9_row3_col5, #T_3e2e9_row3_col6, #T_3e2e9_row4_col0, #T_3e2e9_row4_col1, #T_3e2e9_row4_col2, #T_3e2e9_row4_col3, #T_3e2e9_row4_col4, #T_3e2e9_row4_col5, #T_3e2e9_row5_col0, #T_3e2e9_row5_col1, #T_3e2e9_row5_col2, #T_3e2e9_row5_col3, #T_3e2e9_row5_col4, #T_3e2e9_row5_col5, #T_3e2e9_row5_col6, #T_3e2e9_row6_col0, #T_3e2e9_row6_col1, #T_3e2e9_row6_col2, #T_3e2e9_row6_col3, #T_3e2e9_row6_col4, #T_3e2e9_row6_col5, #T_3e2e9_row6_col6, #T_3e2e9_row7_col0, #T_3e2e9_row7_col1, #T_3e2e9_row7_col2, #T_3e2e9_row7_col3, #T_3e2e9_row7_col4, #T_3e2e9_row7_col5, #T_3e2e9_row7_col6, #T_3e2e9_row8_col0, #T_3e2e9_row8_col1, #T_3e2e9_row8_col2, #T_3e2e9_row8_col3, #T_3e2e9_row8_col4, #T_3e2e9_row8_col5, #T_3e2e9_row8_col6, #T_3e2e9_row9_col0, #T_3e2e9_row9_col1, #T_3e2e9_row9_col2, #T_3e2e9_row9_col3, #T_3e2e9_row9_col4, #T_3e2e9_row9_col5, #T_3e2e9_row9_col6, #T_3e2e9_row10_col0, #T_3e2e9_row10_col1, #T_3e2e9_row10_col2, #T_3e2e9_row10_col3, #T_3e2e9_row10_col4, #T_3e2e9_row10_col5, #T_3e2e9_row10_col6, #T_3e2e9_row11_col0, #T_3e2e9_row11_col1, #T_3e2e9_row11_col2, #T_3e2e9_row11_col3, #T_3e2e9_row11_col4, #T_3e2e9_row11_col6, #T_3e2e9_row12_col0, #T_3e2e9_row12_col1, #T_3e2e9_row12_col2, #T_3e2e9_row12_col3, #T_3e2e9_row12_col4, #T_3e2e9_row12_col5, #T_3e2e9_row12_col6, #T_3e2e9_row13_col0, #T_3e2e9_row13_col1, #T_3e2e9_row13_col2, #T_3e2e9_row13_col3, #T_3e2e9_row13_col4, #T_3e2e9_row13_col5, #T_3e2e9_row13_col6 {
#   text-align: left;
# }
# #T_3e2e9_row0_col1, #T_3e2e9_row0_col2, #T_3e2e9_row0_col3, #T_3e2e9_row0_col4, #T_3e2e9_row4_col6, #T_3e2e9_row11_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3e2e9_row0_col7, #T_3e2e9_row1_col7, #T_3e2e9_row2_col7, #T_3e2e9_row3_col7, #T_3e2e9_row4_col7, #T_3e2e9_row5_col7, #T_3e2e9_row6_col7, #T_3e2e9_row7_col7, #T_3e2e9_row8_col7, #T_3e2e9_row9_col7, #T_3e2e9_row11_col7, #T_3e2e9_row12_col7, #T_3e2e9_row13_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3e2e9_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3e2e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e2e9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3e2e9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3e2e9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3e2e9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3e2e9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3e2e9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3e2e9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3e2e9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e2e9_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_3e2e9_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_3e2e9_row0_col1" class="data row0 col1" >53.6900</td>
#       <td id="T_3e2e9_row0_col2" class="data row0 col2" >251687.2598</td>
#       <td id="T_3e2e9_row0_col3" class="data row0 col3" >484.9996</td>
#       <td id="T_3e2e9_row0_col4" class="data row0 col4" >0.5763</td>
#       <td id="T_3e2e9_row0_col5" class="data row0 col5" >0.8524</td>
#       <td id="T_3e2e9_row0_col6" class="data row0 col6" >1.0233</td>
#       <td id="T_3e2e9_row0_col7" class="data row0 col7" >19.3967</td>
#     </tr>
#     <tr>
#       <th id="T_3e2e9_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_3e2e9_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_3e2e9_row1_col1" class="data row1 col1" >56.5225</td>
#       <td id="T_3e2e9_row1_col2" class="data row1 col2" >382645.2891</td>
#       <td id="T_3e2e9_row1_col3" class="data row1 col3" >562.3022</td>
#       <td id="T_3e2e9_row1_col4" class="data row1 col4" >0.4827</td>
#       <td id="T_3e2e9_row1_col5" class="data row1 col5" >0.8589</td>
#       <td id="T_3e2e9_row1_col6" class="data row1 col6" >0.9806</td>
#       <td id="T_3e2e9_row1_col7" class="data row1 col7" >12.1967</td>
#     </tr>
#     <tr>
#       <th id="T_3e2e9_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_3e2e9_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_3e2e9_row2_col1" class="data row2 col1" >65.8081</td>
#       <td id="T_3e2e9_row2_col2" class="data row2 col2" >588194.5243</td>
#       <td id="T_3e2e9_row2_col3" class="data row2 col3" >730.9947</td>
#       <td id="T_3e2e9_row2_col4" class="data row2 col4" >0.1610</td>
#       <td id="T_3e2e9_row2_col5" class="data row2 col5" >0.9893</td>
#       <td id="T_3e2e9_row2_col6" class="data row2 col6" >1.0245</td>
#       <td id="T_3e2e9_row2_col7" class="data row2 col7" >3.0400</td>
#     </tr>
#     <tr>
#       <th id="T_3e2e9_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_3e2e9_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_3e2e9_row3_col1" class="data row3 col1" >64.3562</td>
#       <td id="T_3e2e9_row3_col2" class="data row3 col2" >602701.6327</td>
#       <td id="T_3e2e9_row3_col3" class="data row3 col3" >732.5403</td>
#       <td id="T_3e2e9_row3_col4" class="data row3 col4" >0.1611</td>
#       <td id="T_3e2e9_row3_col5" class="data row3 col5" >0.9808</td>
#       <td id="T_3e2e9_row3_col6" class="data row3 col6" >1.1530</td>
#       <td id="T_3e2e9_row3_col7" class="data row3 col7" >3.8233</td>
#     </tr>
#     <tr>
#       <th id="T_3e2e9_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_3e2e9_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3e2e9_row4_col1" class="data row4 col1" >62.0747</td>
#       <td id="T_3e2e9_row4_col2" class="data row4 col2" >661993.1412</td>
#       <td id="T_3e2e9_row4_col3" class="data row4 col3" >770.6909</td>
#       <td id="T_3e2e9_row4_col4" class="data row4 col4" >0.0843</td>
#       <td id="T_3e2e9_row4_col5" class="data row4 col5" >0.8826</td>
#       <td id="T_3e2e9_row4_col6" class="data row4 col6" >0.9626</td>
#       <td id="T_3e2e9_row4_col7" class="data row4 col7" >0.2200</td>
#     </tr>
#     <tr>
#       <th id="T_3e2e9_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_3e2e9_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_3e2e9_row5_col1" class="data row5 col1" >71.4001</td>
#       <td id="T_3e2e9_row5_col2" class="data row5 col2" >741330.3054</td>
#       <td id="T_3e2e9_row5_col3" class="data row5 col3" >778.1582</td>
#       <td id="T_3e2e9_row5_col4" class="data row5 col4" >0.1128</td>
#       <td id="T_3e2e9_row5_col5" class="data row5 col5" >1.0416</td>
#       <td id="T_3e2e9_row5_col6" class="data row5 col6" >1.6677</td>
#       <td id="T_3e2e9_row5_col7" class="data row5 col7" >0.9100</td>
#     </tr>
#     <tr>
#       <th id="T_3e2e9_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_3e2e9_row6_col0" class="data row6 col0" >AdaBoost Regressor</td>
#       <td id="T_3e2e9_row6_col1" class="data row6 col1" >75.0080</td>
#       <td id="T_3e2e9_row6_col2" class="data row6 col2" >705220.7480</td>
#       <td id="T_3e2e9_row6_col3" class="data row6 col3" >798.9637</td>
#       <td id="T_3e2e9_row6_col4" class="data row6 col4" >0.0029</td>
#       <td id="T_3e2e9_row6_col5" class="data row6 col5" >1.3044</td>
#       <td id="T_3e2e9_row6_col6" class="data row6 col6" >1.0913</td>
#       <td id="T_3e2e9_row6_col7" class="data row6 col7" >4.4800</td>

# %% [markdown]
# ## Controle

# %%
controle = df_g.query('DESCRICAO_DO_PRODUTO == "NEOLEFRIN XPE FR VD AMB 60ML+COPO MED"')
# create 12 month moving average
controle['MA12'] = controle['QUANTIDADE_TOTAL'].rolling(12).mean()
# plot the controle and MA
import plotly.express as px
fig = px.line(controle, x="DATA_DO_PEDIDO", y=["QUANTIDADE_TOTAL", "MA12"], template = 'plotly_dark')
fig.show()

# %%
# generate predictions on the original dataset
predictions = predict_model(best, data=controle)
# add a date column in the dataset
# predictions['DATA'] = pd.date_range(start='2021-01-01', end = '2021-08-01', freq = 'MS')
# line plot
fig = px.line(predictions, x='DATA_DO_PEDIDO', y=["QUANTIDADE_TOTAL", "Label"], template = 'plotly_dark')
# add a vertical rectange for test-set separation
fig.add_vrect(x0="2021-01-01", x1='2021-08-01', fillcolor="grey", opacity=0.25, line_width=0)
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5004">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5004_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f5004_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f5004_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f5004_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f5004_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f5004_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f5004_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5004_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5004_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_f5004_row0_col1" class="data row0 col1" >4.9262</td>
#       <td id="T_f5004_row0_col2" class="data row0 col2" >448.5469</td>
#       <td id="T_f5004_row0_col3" class="data row0 col3" >21.1789</td>
#       <td id="T_f5004_row0_col4" class="data row0 col4" >0.8343</td>
#       <td id="T_f5004_row0_col5" class="data row0 col5" >0.5233</td>
#       <td id="T_f5004_row0_col6" class="data row0 col6" >0.2310</td>
#     </tr>
#   </tbody>
# </table>

# %%
future_dates = pd.date_range(start = '01/2022', end = '01/2022', freq = 'MS')
future_df = pd.DataFrame()

for preco in range(1,10):

    future_df['DATA_DO_PEDIDO'] = future_dates
    future_df['DATA_DO_PEDIDO'] = pd.to_datetime(future_df['DATA_DO_PEDIDO'], dayfirst=True).dt.strftime('%Y-%m')
    future_df['RAZAO_SOCIAL']='UNIAO DROGARIAS'
    future_df['DESCRICAO_DO_PRODUTO'] = "NEOLEFRIN XPE FR VD AMB 60ML+COPO MED"
    future_df['SUB_BU'] = 'SMART'
    future_df["PRECO_MEDIO"] = preco

    predictions_future = predict_model(best, data=future_df)
    print(preco,predictions_future["Label"][0])
# Out:
# 1 11.822568501770293
# 2 10.44966493832189
# 3 17.016229453237113
# 4 13.864580137566863
# 5 9.810523709996355
# 6 8.90668084816775
# 7 8.331529991980457
# 8 7.021364627154622
# 9 6.069203120762938

# %%
controle.query("RAZAO_SOCIAL == 'UNIAO DROGARIAS' ")
# Out:
#       DATA_DO_PEDIDO     RAZAO_SOCIAL                   DESCRICAO_DO_PRODUTO  \
# 19620        2021-04  UNIAO DROGARIAS  NEOLEFRIN XPE FR VD AMB 60ML+COPO MED
# 26873        2021-06  UNIAO DROGARIAS  NEOLEFRIN XPE FR VD AMB 60ML+COPO MED
# 46657        2021-12  UNIAO DROGARIAS  NEOLEFRIN XPE FR VD AMB 60ML+COPO MED
#
#       SUB_BU  PRECO_MEDIO  QUANTIDADE_TOTAL       MA12
# 19620  SMART         4.68                12  10.333333
# 26873  SMART         5.05                15  26.916667
# 46657  SMART         4.96                12  19.500000
